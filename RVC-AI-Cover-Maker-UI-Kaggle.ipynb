# %% [markdown]
# # **RVC AI Cover Maker UI**
# - Created by [Shirou](https://github.com/ShiromiyaG)
# - Ported by [arisdev](https://github.com/aris-py)
# <br>This kaggle notebook uses the following projects:
# - [Music Source Separation Universal Training Code](https://github.com/ZFTurbo/Music-Source-Separation-Training) by [ZFTurbo](https://github.com/ZFTurbo)
# - [Applio](https://github.com/IAHispano/Applio) by [IAHispano](https://github.com/IAHispano)
#
# ###### Please turn the acelerator with an T4 x2 or P100 GPU

# %% [markdown]
# ## **Install**

# %%
from IPython.display import clear_output
import os
import codecs
print("Installing requirements")
repo = codecs.decode("uggcf://tvguho.pbz/FuvebzvlnT/EIP-NV-Pbire-Znxre-HV.tvg", "rot_13")
# !git clone https://github.com/aris-py/RVC-AI-Cover-Maker-UI-Kaggle.git main_program &> /dev/null
# %cd main_program
clear_output()
print("Installing requirements")
# !pip install uv &> /dev/null
# !pip install git+https://github.com/Vidalnt/imjoy-elfinder > /dev/null 2>&1
# !uv venv .venv &> /dev/null
# !uv pip install --no-deps -r requirements.txt &> /dev/null
# !pip install pyngrok &> /dev/null
# !source .venv/bin/activate; python programs/applio_code/rvc/lib/tools/prerequisites_download.py
print("Requirements installed!")

# %% [markdown]
# ## **Start (With NGROK)**

# %%
from pyngrok import ngrok
import codecs
import os
from IPython.display import clear_output
# %cd /kaggle/working/main_program
clear_output()
os.system(f"imjoy-elfinder --root-dir=/kaggle/working --port 9876 > /dev/null 2>&1 &")
clear_output()
ngrok_token = "TOKEN HERE" # <====https://dashboard.ngrok.com/get-started/your-authtoken====>
ngrok.set_auth_token(ngrok_token)
ngrok.kill()
main_tunnel = ngrok.connect(7755)
file_tunnel = ngrok.connect(9876)
clear_output()
print("RVC URL:", main_tunnel.public_url)
print("File URL:", file_tunnel.public_url)
runtime=codecs.decode("znva.cl", "rot_13")
# !source .venv/bin/activate; python $runtime
